# %% [markdown]
# 2019-02-14 11:54:51

# %% [markdown]
# Trying to rewrite qutip control grape example in away that

# %% [markdown]
# all imports are done in jate.py itself and not just before the location where the functions need to be used

# %% [markdown]
# # Imports

# %% [markdown]
# Need to have jate.py in your folder

# %%
# %run jate.py #will import everything

# %% [markdown]
# # Next chapter

# %% [markdown]
# ## memory clear (uses regex, so be careful)

# %%
# %reset_selective -f var1, var2  # replace var1, var2 with your defined ones

# %% [markdown]
# ## sub topic 2

# %%
total_time = 2*pi
times = linspace(0, total_time, 500)

# %%
U = cnot()
R = 500
H_ops = [tensor(sigmax(), identity(2)),
         tensor(sigmay(), identity(2)),
         tensor(sigmaz(), identity(2)),
         tensor(identity(2), sigmax()),
         tensor(identity(2), sigmay()),
         tensor(identity(2), sigmaz()),
         tensor(sigmax(), sigmax()) +
         tensor(sigmay(), sigmay()) +
         tensor(sigmaz(), sigmaz())]

# %% [markdown]
# $Q$ = Identity in sigle qubit space.
#
# $U = CNOT $
# $H_{ops} = [\sigma_{x} \otimes Q, \sigma_{y} \otimes Q,  \sigma_{z} \otimes Q, Q \otimes \sigma_{x}, Q \otimes \sigma_{y}, Q \otimes \sigma_{z}, \sigma_{x} \otimes \sigma_{x}, \sigma_{y} \otimes \sigma_{y}, \sigma_{z} \otimes \sigma_{z}, ] $

# %%
H_labels = [r'$u_{1x}$', r'$u_{1y}$', r'$u_{1z}$',
            r'$u_{2x}$', r'$u_{1y}$', r'$u_{2z}$',
            r'$u_{xx}$',
            r'$u_{yy}$',
            r'$u_{zz}$',
        ]

# %%
H_labels
# Out:
# ['$u_{1x}$',
#  '$u_{1y}$',
#  '$u_{1z}$',
#  '$u_{2x}$',
#  '$u_{1y}$',
#  '$u_{2z}$',
#  '$u_{xx}$',
#  '$u_{yy}$',
#  '$u_{zz}$']

# %%
H0 = 0 * pi * (tensor(sigmax(), identity(2)) + tensor(identity(2), sigmax()))

c_ops = []

# %% [markdown]
# $H_{0} = 0 * \pi (\sigma_{x} \otimes Q + Q \otimes \sigma_{x})$

# %% [markdown]
#     This is the analytical result in the absence of single-qubit tunnelling.
# $g = \pi/(4 * T)$
# $H = g * (\sigma_{x} \otimes \sigma_{x}) + (\sigma_{y} \otimes \sigma_{y})) $

# %% [markdown]
# # GRAPE

# %% [markdown]
# ## u0 initial

# %%
u0 = array([rand(len(times)) * 2 * pi * 0.05 
               for _ in range(len(H_ops))])
u0
# Out:
# array([[0.27129727, 0.29055191, 0.21138605, ..., 0.22073894, 0.31327265,
#         0.23471607],
#        [0.21777553, 0.17243424, 0.12367299, ..., 0.18045703, 0.1900168 ,
#         0.14480265],
#        [0.02597643, 0.22511119, 0.11198459, ..., 0.31369541, 0.05221385,
#         0.09418634],
#        ...,
#        [0.25230922, 0.09073226, 0.28548485, ..., 0.23671918, 0.11888592,
#         0.19413478],
#        [0.05659043, 0.18492687, 0.26117478, ..., 0.21080076, 0.24282099,
#         0.07653548],
#        [0.08341111, 0.09777545, 0.1424702 , ..., 0.03103212, 0.20965451,
#         0.12752961]])

# %%
len(u0)
# Out:
# 7

# %%
len(u0[0])
# Out:
# 500

# %%
ax = axes()
ax.plot(times, u0[0])
ax.set(xlim=(0, total_time), ylim=(0, 2 * np.pi * 0.05),
       xlabel='times', ylabel='u0_initial',
       title='u0[0] as a function of time');

# %% [markdown]
# ## Plots of u0

# %%
ax = axes()
ax.plot(times, u0[0])
ax.set(xlim=(0, total_time), ylim=(0, 2 * np.pi * 0.05),
       xlabel='times', ylabel='u0[0]_initial',
       title='u0[0] as a function of time');

# %%
ax = axes()
ax.plot(times, u0[1])
ax.set(xlim=(0, total_time), ylim=(0, 2 * np.pi * 0.05),
       xlabel='times', ylabel='u0[1]_initial',
       title='u0[1] as a function of time');

# %%
ax = axes()
ax.plot(times, u0[2])
ax.set(xlim=(0, total_time), ylim=(0, 2 * np.pi * 0.05),
       xlabel='times', ylabel='u0[2]_initial',
       title='u0[2] as a function of time');

# %%
ax = axes()
ax.plot(times, u0[3])
ax.set(xlim=(0, total_time), ylim=(0, 2 * np.pi * 0.05),
       xlabel='times', ylabel='u0[3]_initial',
       title='u0[3] as a function of time');

# %%
ax = axes()
ax.plot(times, u0[1])
ax.set(xlim=(0, total_time), ylim=(0, 2 * np.pi * 0.05),
       xlabel='times', ylabel='u0[1]_initial',
       title='u0[1] as a function of time');

# %%
ax = axes()
ax.plot(times, u0[1])
ax.set(xlim=(0, total_time), ylim=(0, 2 * np.pi * 0.05),
       xlabel='times', ylabel='u0[1]_initial',
       title='u0[1] as a function of time');

# %%
ax = axes()
ax.plot(times, u0[1])
ax.set(xlim=(0, total_time), ylim=(0, 2 * np.pi * 0.05),
       xlabel='times', ylabel='u0[1]_initial',
       title='u0[1] as a function of time');

# %%
ax = axes()
ax.plot(times, u0[1])
ax.set(xlim=(0, total_time), ylim=(0, 2 * np.pi * 0.05),
       xlabel='times', ylabel='u0[1]_initial',
       title='u0[1] as a function of time');

# %%
ax = axes()
ax.plot(times, u0[1])
ax.set(xlim=(0, total_time), ylim=(0, 2 * np.pi * 0.05),
       xlabel='times', ylabel='u0[1]_initial',
       title='u0[1] as a function of time');

# %%
ax = axes()
ax.plot(times, u0[1])
ax.set(xlim=(0, total_time), ylim=(0, 2 * np.pi * 0.05),
       xlabel='times', ylabel='u0[1]_initial',
       title='u0[1] as a function of time');

# %% [markdown]
# ## u0 after convolution

# %%
u0 = [convolve(ones(10)/10, u0[idx,:], mode='same')
      for idx in range(len(H_ops))]
u0
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-23-3986ec6c8696> in <module>()
#       1 u0 = [convolve(ones(10)/10, u0[idx,:], mode='same')
# ----> 2       for idx in range(len(H_ops))]
#       3 u0
#
# <ipython-input-23-3986ec6c8696> in <listcomp>(.0)
#       1 u0 = [convolve(ones(10)/10, u0[idx,:], mode='same')
# ----> 2       for idx in range(len(H_ops))]
#       3 u0
#
# NameError: name 'convolve' is not defined

# %% [markdown]
# ## Explaining ulimits, alpha

# %%
u_limits = None #[0, 1 * 2 * pi]
alpha = None

# %% [markdown]
# ## understanding cy_grape_unitary

# %%
result = cy_grape_unitary(U, H0, H_ops, R, times, u_start=u0, u_limits=u_limits,
                          eps=2*np.pi*1, alpha=alpha, phase_sensitive=False,
                          progress_bar=TextProgressBar())
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-25-1cb301d5355f> in <module>()
# ----> 1 result = cy_grape_unitary(U, H0, H_ops, R, times, u_start=u0, u_limits=u_limits,
#       2                           eps=2*np.pi*1, alpha=alpha, phase_sensitive=False,
#       3                           progress_bar=TextProgressBar())
#
# NameError: name 'cy_grape_unitary' is not defined

# %% [raw]
# U_f, H_list_func, u = grape_unitary_adaptive(U, H0,
# H_ops, R, times,u_start=u0, u_limits=u_limits, eps=2*pi*1,
# alpha=alpha, phase_sensitive=False, overlap_terminate=0.9999,
# progress_bar=TextProgressBar())

# %% [markdown]
# ## Plot control fields for cnot gate in the presense of single-qubit tunnelling

# %% [markdown]
# plot_grape_control_fields(times, u, labels, uniform_axes=False):
#     """
#     Plot a series of plots showing the GRAPE control fields given in the
#     given control pulse matrix u.
#
#     Parameters
#     ----------
#     times : array
#         Time coordinate array.
#
#     u : array
#         Control pulse matrix.
#
#     labels : list
#         List of labels for each control pulse sequence in the control pulse
#         matrix.
#
#     uniform_axes : bool
#         Whether or not to plot all pulse sequences using the same y-axis scale.
#
#     """

# %%
plot_grape_control_fields(times,
                          result.u / (2 * np.pi), H_labels, uniform_axes=True);

# %% [markdown]
# ## sub topic 3

# %% [markdown]
# ### sub sub topic 1

# %%
from numpy import convolve, clip

# %%
convolve(rand(5), rand(5))
# Out:
# array([0.23199111, 0.74553607, 1.14061003, 1.30772351, 1.26045701,
#        1.03342204, 0.9121795 , 0.46613187, 0.03698775])

# %% [markdown]
# ## Versions

# %%
version_table()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-4b57e2ca0b8f> in <module>()
# ----> 1 version_table()
#
# NameError: name 'version_table' is not defined
